# %% [markdown]
# # Major Survey Results Project 1 Part 2- Mitra Iyer - 10/7/25

# %% [markdown]
# ## This is project shows the information about the data frame detailing student responses on the student life, classes, and more at CCM. The first part gives information about the data frame and the second part cleans the data frame to answer my data science questions and remove uneccessary values.

# %% [markdown]
# #### import pandas

# %%
import pandas as pd

# %% [markdown]
# #### read in csv

# %%
data = pd.read_csv('MajorsSurveyResults24.csv')

# %% [markdown]
# #### describes data

# %%
data.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?
# count                                          62.000000
# mean                                            3.580645
# std                                             1.079593
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# #### returns all the columns

# %%
data.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### returns the width/length of data

# %%
data.shape
# Out:
# (197, 90)

# %% [markdown]
# #### returns all the data types

# %%
data.dtypes
# Out:
# Timestamp                                                                                                                                               object
# Which course are you enrolled in?                                                                                                                       object
# How did you hear about County College of Morris? [CCM Web site]                                                                                         object
# How did you hear about County College of Morris? [Social Media]                                                                                         object
# How did you hear about County College of Morris? [Community Event]                                                                                      object
#                                                                                                                                                         ...
# ...

# %% [markdown]
# #### returns top rows of the data set

# %%
data.head()
# Out:
#                     Timestamp Which course are you enrolled in?  \
# 0  2024/09/09 12:33:58 PM AST        CMP 128 Computer Science I
# 1   2024/09/09 6:00:11 PM AST                               NaN
# 2   2024/09/10 9:00:12 AM AST        CMP 128 Computer Science I
# 3  2024/09/10 12:34:53 PM AST        CMP 128 Computer Science I
# 4   2024/09/10 3:06:47 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# #### returns bottom rows of data set

# %%
data.tail()
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 192                                       Don't recall
# 193                                                Yes
# 194                                                Yes
# 195                                                Yes
# 196                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 192                                       Don't recall
# ...

# %% [markdown]
# #### returns random sample of items

# %%
data.sample()
# Out:
#                      Timestamp Which course are you enrolled in?  \
# 172  2024/09/16 9:56:07 AM AST        CMP 128 Computer Science I
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 172                                                Yes
#
#     How did you hear about County College of Morris? [Social Media]  \
# 172                                                 No
#
#     How did you hear about County College of Morris? [Community Event]  \
# 172                                                 No
#
#     How did you hear about County College of Morris? [Family member or friend]  \
# 172                                                Yes
#
#     How did you hear about County College of Morris? [Current CCM student]  \
# 172                                                 No
#
#     How did you hear about County College of Morris? [CCM Alumni]  \
# 172                                                 No
#
# ...

# %% [markdown]
# #### returns summary of dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 90 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        197 non-null    object
# ...

# %% [markdown]
# ## Cleaning the Data set

# %% [markdown]
# ### Purpose of data cleaning: I want to remove the columns I do not need, make them have shorter lowercase names, as well as remove nAn values. This is to answer my questions efficiently which I wrote down below.

# %% [markdown]
# ### Data Science Questions:
#     1. What are the order courses that students enrolled in had the most participants in campus events or activities?
#     2. What is the order of majors that havethe most students who were exposed to computing classes in middle or high school?
#     3. What are the majors that have the fewest people who identify as a woman?
#     4. From which source did the most students receive information about CCM’s computing programs?  Which source did the least students hear information about CCM's computing programs?
#     5. Which age group is least represented in computing?

# %% [markdown]
# #### Show head of the data before transformations

# %%
data.head()
# Out:
#                     Timestamp Which course are you enrolled in?  \
# 0  2024/09/09 12:33:58 PM AST        CMP 128 Computer Science I
# 1   2024/09/09 6:00:11 PM AST                               NaN
# 2   2024/09/10 9:00:12 AM AST        CMP 128 Computer Science I
# 3  2024/09/10 12:34:53 PM AST        CMP 128 Computer Science I
# 4   2024/09/10 3:06:47 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# #### I am printing the tail of the data to show data at the end of the data frame as well

# %%
data.tail()
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 192                                       Don't recall
# 193                                                Yes
# 194                                                Yes
# 195                                                Yes
# 196                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 192                                       Don't recall
# ...

# %% [markdown]
# #### Show all the columns so that I am able to see all the names in one place

# %%
data.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### Find indexes of columns so I can remove them - I created a map that maps the col names to the indexes

# %%
col_index_map = {col_name: i for i, col_name in enumerate(data.columns)}

# %% [markdown]
# #### Print column names and indexes

# %%
col_index_map
# Out:
# {'Timestamp': 0,
#  'Which course are you enrolled in?': 1,
#  'How did you hear about County College of Morris? [CCM Web site]': 2,
#  'How did you hear about County College of Morris? [Social Media]': 3,
#  'How did you hear about County College of Morris? [Community Event]': 4,
#  'How did you hear about County College of Morris? [Family member or friend]': 5,
#  'How did you hear about County College of Morris? [Current CCM student]': 6,
#  'How did you hear about County College of Morris? [CCM Alumni]': 7,
#  'How did you hear about County College of Morris? [High School Teacher]': 8,
#  'How did you hear about County College of Morris? [High School Counselor]': 9,
#  'How did you hear about County College of Morris? [In-app advertisement]': 10,
#  'How did you hear about County College of Morris? [Employer]': 11,
#  'How did you hear about County College of Morris? [Billboard]': 12,
#  'How did you hear about County College of Morris? [Television]': 13,
# ...

# %% [markdown]
# #### Remove unneccesary columns based on my questions - I used a list for this and range so I could drop multiple columns

# %%
columnsToDrop = list(range(16,32)) + list(range(50,53)) +  list(range(55,62)) + list(range(84,87)) + [88]

# %%
data = data.drop(data.columns[columnsToDrop], axis = 1)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### Now I am remapping all the column names to make them easier to access

# %%
rename_columns = {
    'Timestamp': 'timestamp',
    'Which course are you enrolled in?': 'course_enrolled',
    'How did you hear about County College of Morris? [CCM Web site]': 'hear_ccm_website',
    'How did you hear about County College of Morris? [Social Media]': 'hear_social_media',
    'How did you hear about County College of Morris? [Community Event]': 'hear_community_event',
    'How did you hear about County College of Morris? [Family member or friend]': 'hear_family_friend',
    'How did you hear about County College of Morris? [Current CCM student]': 'hear_current_student',
    'How did you hear about County College of Morris? [CCM Alumni]': 'hear_alumni',
    'How did you hear about County College of Morris? [High School Teacher]': 'hear_hs_teacher',
    'How did you hear about County College of Morris? [High School Counselor]': 'hear_hs_counselor',
    'How did you hear about County College of Morris? [In-app advertisement]': 'hear_inapp_ad',
    'How did you hear about County College of Morris? [Employer]': 'hear_employer',
    'How did you hear about County College of Morris? [Billboard]': 'hear_billboard',
    'How did you hear about County College of Morris? [Television]': 'hear_tv',
    'How did you hear about County College of Morris? [Radio]': 'hear_radio',
    'How did you hear about County College of Morris? [Other]': 'hear_other',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'event_open_house',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'event_instant_decision_day',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'event_oncampus_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]': 'event_titans_tuesday_virtual',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'event_women_who_dare',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'event_college_fair',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'event_hs_sharetime_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'event_challenger_program',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'event_cybersecurity_program',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'event_hs_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'event_hs_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'event_individual_campus_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'event_workforce_class',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'event_corporate_training',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': "event_teens_arts",
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': "event_ccm_summer_camp",
    
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]': 'impact_hs_computing_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]': 'impact_hs_computing_club',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]': 'impact_ap_computing_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]': 'impact_dual_enrollment',
    'What degree program are you currently enrolled in?': 'degree_program',
    'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]': 'motivation_job',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor\'s level program]': 'motivation_transfer_bachelors',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]': 'motivation_transfer_hs',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]': 'motivation_career_advancement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]': 'motivation_career_change',
    'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]': 'motivation_professional_dev',
    'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]': 'motivation_job_displacement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]': 'motivation_relocation',
    'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]': 'motivation_keep_current',
    'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]': 'motivation_certifications',
    'What motivated you to seek a computing degree/certificate at CCM?  [Financial]': 'motivation_financial',
    'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]': 'motivation_enrichment',
    'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]': 'info_hs_counselor',
    'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]': 'info_hs_teacher',
    'Did you receive information about the CCM computing programs from any of the following sources? [Employer]': 'info_employer',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]': 'info_ccm_workforce_development',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]' : 'info_ccm_advisor',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]': 'info_ccm_website',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]': 'info_ccm_admissions',
    'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]' : 'info_nj_workforce_development',
    'Did you receive information about the CCM computing programs from any of the following sources? [Other]' : 'info.other',
    'Age ': 'age',
    'Gender': 'gender'
}

# %%
data = data.rename(columns=rename_columns)

# %%
data.columns
# Out:
# Index(['timestamp', 'course_enrolled', 'hear_ccm_website', 'hear_social_media',
#        'hear_community_event', 'hear_family_friend', 'hear_current_student',
#        'hear_alumni', 'hear_hs_teacher', 'hear_hs_counselor', 'hear_inapp_ad',
#        'hear_employer', 'hear_billboard', 'hear_tv', 'hear_radio',
#        'hear_other', 'event_open_house', 'event_instant_decision_day',
#        'event_oncampus_info_session', 'event_titans_tuesday_virtual',
#        'event_women_who_dare', 'event_college_fair',
#        'event_hs_sharetime_session', 'event_challenger_program',
#        'event_cybersecurity_program', 'event_hs_info_session',
#        'event_hs_campus_visit', 'event_individual_campus_visit',
#        'event_workforce_class', 'event_corporate_training', 'event_teens_arts',
#        'event_ccm_summer_camp', 'impact_hs_computing_class',
#        'impact_hs_computing_club', 'impact_ap_computing_class',
#        'impact_dual_enrollment', 'degree_program', 'motivation_job',
# ...

# %%
data.head()
# Out:
#                     timestamp             course_enrolled hear_ccm_website  \
# 0  2024/09/09 12:33:58 PM AST  CMP 128 Computer Science I              Yes
# 1   2024/09/09 6:00:11 PM AST                         NaN               No
# 2   2024/09/10 9:00:12 AM AST  CMP 128 Computer Science I               No
# 3  2024/09/10 12:34:53 PM AST  CMP 128 Computer Science I              Yes
# 4   2024/09/10 3:06:47 PM AST  CMP 128 Computer Science I               No
#
#   hear_social_media hear_community_event hear_family_friend  \
# 0               Yes                  Yes                Yes
# 1                No                  Yes                 No
# 2                No                   No                Yes
# 3               Yes                  Yes                Yes
# 4                No                   No                Yes
#
#   hear_current_student hear_alumni hear_hs_teacher hear_hs_counselor  ...  \
# 0                  Yes         Yes             Yes               Yes  ...
# ...

# %%
data.columns
# Out:
# Index(['timestamp', 'course_enrolled', 'hear_ccm_website', 'hear_social_media',
#        'hear_community_event', 'hear_family_friend', 'hear_current_student',
#        'hear_alumni', 'hear_hs_teacher', 'hear_hs_counselor', 'hear_inapp_ad',
#        'hear_employer', 'hear_billboard', 'hear_tv', 'hear_radio',
#        'hear_other', 'event_open_house', 'event_instant_decision_day',
#        'event_oncampus_info_session', 'event_titans_tuesday_virtual',
#        'event_women_who_dare', 'event_college_fair',
#        'event_hs_sharetime_session', 'event_challenger_program',
#        'event_cybersecurity_program', 'event_hs_info_session',
#        'event_hs_campus_visit', 'event_individual_campus_visit',
#        'event_workforce_class', 'event_corporate_training', 'event_teens_arts',
#        'event_ccm_summer_camp', 'impact_hs_computing_class',
#        'impact_hs_computing_club', 'impact_ap_computing_class',
#        'impact_dual_enrollment', 'degree_program', 'motivation_job',
# ...

# %% [markdown]
# #### Find duplicates in data

# %%
duplicates = data.duplicated().sum()

# %%
duplicates
# Out:
# np.int64(0)

# %% [markdown]
# #### Taking out nAn values in the columns so I can understand the data better

# %%
data.head()
# Out:
#                     timestamp             course_enrolled hear_ccm_website  \
# 0  2024/09/09 12:33:58 PM AST  CMP 128 Computer Science I              Yes
# 1   2024/09/09 6:00:11 PM AST                         NaN               No
# 2   2024/09/10 9:00:12 AM AST  CMP 128 Computer Science I               No
# 3  2024/09/10 12:34:53 PM AST  CMP 128 Computer Science I              Yes
# 4   2024/09/10 3:06:47 PM AST  CMP 128 Computer Science I               No
#
#   hear_social_media hear_community_event hear_family_friend  \
# 0               Yes                  Yes                Yes
# 1                No                  Yes                 No
# 2                No                   No                Yes
# 3               Yes                  Yes                Yes
# 4                No                   No                Yes
#
#   hear_current_student hear_alumni hear_hs_teacher hear_hs_counselor  ...  \
# 0                  Yes         Yes             Yes               Yes  ...
# ...

# %%
motivationCols = ['motivation_relocation','motivation_keep_current', 'motivation_certifications','motivation_financial','motivation_enrichment']
data[motivationCols] = data[motivationCols].fillna('No Response')

# %%
infoCols = [col for col in data.columns if col.startswith('info_')]
data[infoCols] = data[infoCols].fillna('No Response')

# %%
data.columns
# Out:
# Index(['timestamp', 'course_enrolled', 'hear_ccm_website', 'hear_social_media',
#        'hear_community_event', 'hear_family_friend', 'hear_current_student',
#        'hear_alumni', 'hear_hs_teacher', 'hear_hs_counselor', 'hear_inapp_ad',
#        'hear_employer', 'hear_billboard', 'hear_tv', 'hear_radio',
#        'hear_other', 'event_open_house', 'event_instant_decision_day',
#        'event_oncampus_info_session', 'event_titans_tuesday_virtual',
#        'event_women_who_dare', 'event_college_fair',
#        'event_hs_sharetime_session', 'event_challenger_program',
#        'event_cybersecurity_program', 'event_hs_info_session',
#        'event_hs_campus_visit', 'event_individual_campus_visit',
#        'event_workforce_class', 'event_corporate_training', 'event_teens_arts',
#        'event_ccm_summer_camp', 'impact_hs_computing_class',
#        'impact_hs_computing_club', 'impact_ap_computing_class',
#        'impact_dual_enrollment', 'degree_program', 'motivation_job',
# ...

# %%
data.head()
# Out:
#                     timestamp             course_enrolled hear_ccm_website  \
# 0  2024/09/09 12:33:58 PM AST  CMP 128 Computer Science I              Yes
# 1   2024/09/09 6:00:11 PM AST                         NaN               No
# 2   2024/09/10 9:00:12 AM AST  CMP 128 Computer Science I               No
# 3  2024/09/10 12:34:53 PM AST  CMP 128 Computer Science I              Yes
# 4   2024/09/10 3:06:47 PM AST  CMP 128 Computer Science I               No
#
#   hear_social_media hear_community_event hear_family_friend  \
# 0               Yes                  Yes                Yes
# 1                No                  Yes                 No
# 2                No                   No                Yes
# 3               Yes                  Yes                Yes
# 4                No                   No                Yes
#
#   hear_current_student hear_alumni hear_hs_teacher hear_hs_counselor  ...  \
# 0                  Yes         Yes             Yes               Yes  ...
# ...

# %% [markdown]
# #### Show data head and tail after it was cleaned to check difference

# %%
data.head()
# Out:
#                     timestamp             course_enrolled hear_ccm_website  \
# 0  2024/09/09 12:33:58 PM AST  CMP 128 Computer Science I              Yes
# 1   2024/09/09 6:00:11 PM AST                         NaN               No
# 2   2024/09/10 9:00:12 AM AST  CMP 128 Computer Science I               No
# 3  2024/09/10 12:34:53 PM AST  CMP 128 Computer Science I              Yes
# 4   2024/09/10 3:06:47 PM AST  CMP 128 Computer Science I               No
#
#   hear_social_media hear_community_event hear_family_friend  \
# 0               Yes                  Yes                Yes
# 1                No                  Yes                 No
# 2                No                   No                Yes
# 3               Yes                  Yes                Yes
# 4                No                   No                Yes
#
#   hear_current_student hear_alumni hear_hs_teacher hear_hs_counselor  ...  \
# 0                  Yes         Yes             Yes               Yes  ...
# ...

# %%
data.tail()
# Out:
#                       timestamp                               course_enrolled  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#     hear_ccm_website hear_social_media hear_community_event  \
# 192     Don't recall      Don't recall         Don't recall
# 193              Yes                No                   No
# 194              Yes      Don't recall                   No
# 195              Yes                No                   No
# 196               No                No                   No
#
#     hear_family_friend hear_current_student   hear_alumni hear_hs_teacher  \
# ...

# %%
#### Put data into a new cleaned csv file

# %%
data.to_csv('MajorSurveyResults24_cleaned_data.csv', index=False)

# %% [markdown]
# #### Citations:
#     ChatGPT - Renaming the columns
#     https://saturncloud.io/blog/how-to-get-column-index-from-column-name-in-python-pandas/ - Getting column index
